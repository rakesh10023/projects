# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
df  = pd.read_csv('JEE_Dropout_After_Class_12.csv')

# %%
df.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# ...

# %%
df.isnull().sum()
# Out:
# jee_main_score             0
# jee_advanced_score         0
# mock_test_score_avg        0
# school_board               0
# class_12_percent           0
# attempt_count              0
# coaching_institute      1209
# daily_study_hours          0
# family_income              0
# parent_education           0
# location_type              0
# peer_pressure_level        0
# mental_health_issues       0
# admission_taken            0
# dropout                    0
# dtype: int64

# %%
df.describe()
# Out:
#        jee_main_score  jee_advanced_score  mock_test_score_avg  \
# count     5000.000000         5000.000000          5000.000000
# mean        71.961226           65.736404            68.110756
# std         13.668497           15.909248            11.938849
# min         26.620000            3.240000            27.490000
# 25%         62.790000           55.017500            60.070000
# 50%         72.190000           65.720000            68.120000
# 75%         81.322500           76.835000            76.110000
# max        100.000000          100.000000           100.000000
#
#        class_12_percent  attempt_count  daily_study_hours      dropout
# count       5000.000000    5000.000000        5000.000000  5000.000000
# mean          74.957400       1.504600           4.483860     0.207200
# std            9.885309       0.500029           1.984723     0.405341
# min           50.000000       1.000000           0.000000     0.000000
# ...

# %%
df['coaching_institute'].unique()
# Out:
# array(['FIITJEE', 'Allen', 'Local', nan], dtype=object)

# %%
df['coaching_institute'].mode()
# Out:
# 0    FIITJEE
# Name: coaching_institute, dtype: object

# %%
df.fillna(df['coaching_institute'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# jee_main_score          0
# jee_advanced_score      0
# mock_test_score_avg     0
# school_board            0
# class_12_percent        0
# attempt_count           0
# coaching_institute      0
# daily_study_hours       0
# family_income           0
# parent_education        0
# location_type           0
# peer_pressure_level     0
# mental_health_issues    0
# admission_taken         0
# dropout                 0
# dtype: int64

# %%
df.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# ...

# %%
df['jee_main_score'].value_counts()
# Out:
# jee_main_score
# 100.00    112
# 81.70       6
# 76.54       6
# 68.72       6
# 78.63       6
#          ...
# 62.42       1
# 86.11       1
# 91.87       1
# 90.50       1
# 79.93       1
# Name: count, Length: 3113, dtype: int64

# %%
df['jee_advanced_score'].value_counts()
# Out:
# jee_advanced_score
# 100.00    88
# 65.34      7
# 74.49      6
# 66.03      5
# 68.17      5
#           ..
# 34.38      1
# 56.87      1
# 47.13      1
# 66.62      1
# 73.93      1
# Name: count, Length: 3304, dtype: int64

# %%
df['school_board'].value_counts()
# Out:
# school_board
# CBSE     1738
# ICSE     1660
# State    1602
# Name: count, dtype: int64

# %%
df['class_12_percent'].value_counts()
# Out:
# class_12_percent
# 50.00     33
# 100.00    24
# 78.96      8
# 74.18      7
# 77.52      7
#           ..
# 79.11      1
# 80.19      1
# 86.64      1
# 68.96      1
# 94.90      1
# Name: count, Length: 2776, dtype: int64

# %%
df['attempt_count'].value_counts()
# Out:
# attempt_count
# 2    2523
# 1    2477
# Name: count, dtype: int64

# %%
df['daily_study_hours'].value_counts()
# Out:
# daily_study_hours
# 4.4    117
# 4.7    114
# 3.9    106
# 4.8    103
# 4.5    100
#       ...
# 9.7      4
# 9.8      3
# 9.9      3
# 0.1      3
# 9.2      1
# Name: count, Length: 101, dtype: int64

# %%
df['family_income'].value_counts()
# Out:
# family_income
# Low     1679
# High    1663
# Mid     1658
# Name: count, dtype: int64

# %%
df['parent_education'].value_counts()
# Out:
# parent_education
# Upto 10th    1288
# PG           1245
# 12th         1243
# Graduate     1224
# Name: count, dtype: int64

# %%
df['parent_education'].value_counts()
# Out:
# parent_education
# Upto 10th    1288
# PG           1245
# 12th         1243
# Graduate     1224
# Name: count, dtype: int64

# %%
df['mental_health_issues'].value_counts()
# Out:
# mental_health_issues
# No     2574
# Yes    2426
# Name: count, dtype: int64

# %%
df['dropout'].value_counts()
# Out:
# dropout
# 0    3964
# 1    1036
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pylab as plt

# %%
df.dtypes
# Out:
# jee_main_score          float64
# jee_advanced_score      float64
# mock_test_score_avg     float64
# school_board             object
# class_12_percent        float64
# attempt_count             int64
# coaching_institute       object
# daily_study_hours       float64
# family_income            object
# parent_education         object
# location_type            object
# peer_pressure_level      object
# mental_health_issues     object
# admission_taken          object
# dropout                   int64
# dtype: object

# %%
Numrarical_columns = df.columns[df.dtypes == 'float']

# %%
Numrarical_columns
# Out:
# Index(['jee_main_score', 'jee_advanced_score', 'mock_test_score_avg',
#        'class_12_percent', 'daily_study_hours'],
#       dtype='object')

# %%
df.columns[df.dtypes != 'float64']
# Out:
# Index(['school_board', 'attempt_count', 'coaching_institute', 'family_income',
#        'parent_education', 'location_type', 'peer_pressure_level',
#        'mental_health_issues', 'admission_taken', 'dropout'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
x=0
for i in df:
    sns.histplot(data=df,x=i,kde=True)
    plt.show()
