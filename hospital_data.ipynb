# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
# %matplotlib inline

# %%
ba =  pd.read_csv('https://raw.githubusercontent.com/donnemartin/hospital-quality/refs/heads/master/hospital-data.csv')

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1  Address 2  Address 3      City State  ZIP Code  \
# 0      1108 ROSS CLARK CIRCLE        NaN        NaN    DOTHAN    AL     36301
# 1  2505 U S HIGHWAY 431 NORTH        NaN        NaN      BOAZ    AL     35957
# 2          205 MARENGO STREET        NaN        NaN  FLORENCE    AL     35631
# 3               702 N MAIN ST        NaN        NaN       OPP    AL     36467
# 4         101 HOSPITAL CIRCLE        NaN        NaN   LUVERNE    AL     36049
#
#        County  Phone Number         Hospital Type  \
# 0     HOUSTON    3347938701  Acute Care Hospitals
# 1    MARSHALL    2565938310  Acute Care Hospitals
# ...

# %%
ba.shape
# Out:
# (4826, 13)

# %%
ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4826 entries, 0 to 4825
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider Number     4826 non-null   object
#  1   Hospital Name       4826 non-null   object
#  2   Address 1           4826 non-null   object
#  3   Address 2           0 non-null      float64
#  4   Address 3           0 non-null      float64
#  5   City                4826 non-null   object
#  6   State               4826 non-null   object
#  7   ZIP Code            4826 non-null   int64
#  8   County              4805 non-null   object
#  9   Phone Number        4826 non-null   int64
#  10  Hospital Type       4826 non-null   object
#  11  Hospital Ownership  4826 non-null   object
#  12  Emergency Services  4826 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 490.3+ KB

# %%
ba.isnull().sum()
# Out:
# Provider Number          0
# Hospital Name            0
# Address 1                0
# Address 2             4826
# Address 3             4826
# City                     0
# State                    0
# ZIP Code                 0
# County                  21
# Phone Number             0
# Hospital Type            0
# Hospital Ownership       0
# Emergency Services       0
# dtype: int64

# %%
ba.columns
# Out:
# Index(['Provider Number', 'Hospital Name', 'Address 1', 'Address 2',
#        'Address 3', 'City', 'State', 'ZIP Code', 'County', 'Phone Number',
#        'Hospital Type', 'Hospital Ownership', 'Emergency Services'],
#       dtype='object')

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1  Address 2  Address 3      City State  ZIP Code  \
# 0      1108 ROSS CLARK CIRCLE        NaN        NaN    DOTHAN    AL     36301
# 1  2505 U S HIGHWAY 431 NORTH        NaN        NaN      BOAZ    AL     35957
# 2          205 MARENGO STREET        NaN        NaN  FLORENCE    AL     35631
# 3               702 N MAIN ST        NaN        NaN       OPP    AL     36467
# 4         101 HOSPITAL CIRCLE        NaN        NaN   LUVERNE    AL     36049
#
#        County  Phone Number         Hospital Type  \
# 0     HOUSTON    3347938701  Acute Care Hospitals
# 1    MARSHALL    2565938310  Acute Care Hospitals
# ...

# %%
ba.drop(columns='Address 2',axis=1,inplace=True)

# %%
ba.shape
# Out:
# (4826, 12)

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1  Address 3      City State  ZIP Code  \
# 0      1108 ROSS CLARK CIRCLE        NaN    DOTHAN    AL     36301
# 1  2505 U S HIGHWAY 431 NORTH        NaN      BOAZ    AL     35957
# 2          205 MARENGO STREET        NaN  FLORENCE    AL     35631
# 3               702 N MAIN ST        NaN       OPP    AL     36467
# 4         101 HOSPITAL CIRCLE        NaN   LUVERNE    AL     36049
#
#        County  Phone Number         Hospital Type  \
# 0     HOUSTON    3347938701  Acute Care Hospitals
# 1    MARSHALL    2565938310  Acute Care Hospitals
# 2  LAUDERDALE    2567688400  Acute Care Hospitals
# ...

# %%
ba.drop(columns='Address 3',axis=1,inplace=True)

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1      City State  ZIP Code      County  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301     HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 2          205 MARENGO STREET  FLORENCE    AL     35631  LAUDERDALE
# 3               702 N MAIN ST       OPP    AL     36467   COVINGTON
# 4         101 HOSPITAL CIRCLE   LUVERNE    AL     36049    CRENSHAW
#
#    Phone Number         Hospital Type  \
# 0    3347938701  Acute Care Hospitals
# 1    2565938310  Acute Care Hospitals
# 2    2567688400  Acute Care Hospitals
# 3    3344933541  Acute Care Hospitals
# 4    3343353374  Acute Care Hospitals
#
# ...

# %%
ba.shape
# Out:
# (4826, 11)

# %%
ba.isnull().sum()
# Out:
# Provider Number        0
# Hospital Name          0
# Address 1              0
# City                   0
# State                  0
# ZIP Code               0
# County                21
# Phone Number           0
# Hospital Type          0
# Hospital Ownership     0
# Emergency Services     0
# dtype: int64

# %%
ba['County'].mode()
# Out:
# 0    LOS ANGELES
# Name: County, dtype: object

# %%
ba.fillna(ba['County'].mode()[0],inplace=True)

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1      City State  ZIP Code      County  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301     HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 2          205 MARENGO STREET  FLORENCE    AL     35631  LAUDERDALE
# 3               702 N MAIN ST       OPP    AL     36467   COVINGTON
# 4         101 HOSPITAL CIRCLE   LUVERNE    AL     36049    CRENSHAW
#
#    Phone Number         Hospital Type  \
# 0    3347938701  Acute Care Hospitals
# 1    2565938310  Acute Care Hospitals
# 2    2567688400  Acute Care Hospitals
# 3    3344933541  Acute Care Hospitals
# 4    3343353374  Acute Care Hospitals
#
# ...

# %%
ba.isnull().sum()
# Out:
# Provider Number       0
# Hospital Name         0
# Address 1             0
# City                  0
# State                 0
# ZIP Code              0
# County                0
# Phone Number          0
# Hospital Type         0
# Hospital Ownership    0
# Emergency Services    0
# dtype: int64

# %%
ba.head(2)
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
#
#                     Address 1    City State  ZIP Code    County  Phone Number  \
# 0      1108 ROSS CLARK CIRCLE  DOTHAN    AL     36301   HOUSTON    3347938701
# 1  2505 U S HIGHWAY 431 NORTH    BOAZ    AL     35957  MARSHALL    2565938310
#
#           Hospital Type                           Hospital Ownership  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority
# 1  Acute Care Hospitals  Government - Hospital District or Authority
#
#   Emergency Services
# 0                Yes
# 1                Yes

# %%
ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4826 entries, 0 to 4825
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider Number     4826 non-null   object
#  1   Hospital Name       4826 non-null   object
#  2   Address 1           4826 non-null   object
#  3   City                4826 non-null   object
#  4   State               4826 non-null   object
#  5   ZIP Code            4826 non-null   int64
#  6   County              4826 non-null   object
#  7   Phone Number        4826 non-null   int64
#  8   Hospital Type       4826 non-null   object
#  9   Hospital Ownership  4826 non-null   object
#  10  Emergency Services  4826 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 414.9+ KB

# %%
ba['Provider Number'].unique()
# Out:
# array(['010001', '010005', '010006', ..., '670075', '670076', '670077'],
#       dtype=object)

# %%
type('010006')
# Out:
# str

# %%
'010006'.isnumeric()
# Out:
# True

# %%
'010006M'.isnumeric()
# Out:
# False

# %%
ba[~ba['Provider Number'].str.isnumeric()]
# Out:
#      Provider Number                                      Hospital Name  \
# 88            01014F                       BIRMINGHAM VA MEDICAL CENTER
# 97            01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 98            01021F                       TUSCALOOSA VA MEDICAL CENTER
# 183           03012F                          PHOENIX VA MEDICAL CENTER
# 186           03013F                    VA S. ARIZONA HEALTHCARE SYSTEM
# ...              ...                                                ...
# 4634          52002F                            TOMAH VA MEDICAL CENTER
# 4641          52003F                        MILWAUKEE VA MEDICAL CENTER
# 4647          52004F                          MADISON VA MEDICAL CENTER
# 4761          53004F                         CHEYENNE VA MEDICAL CENTER
# 4762          53005F                         SHERIDAN VA MEDICAL CENTER
#
#                       Address 1                            City State  \
# ...

# %%
ba.replace('F','',inplace=True)

# %%
ba[~ba['Provider Number'].str.isnumeric()]
# Out:
#      Provider Number                                      Hospital Name  \
# 88            01014F                       BIRMINGHAM VA MEDICAL CENTER
# 97            01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 98            01021F                       TUSCALOOSA VA MEDICAL CENTER
# 183           03012F                          PHOENIX VA MEDICAL CENTER
# 186           03013F                    VA S. ARIZONA HEALTHCARE SYSTEM
# ...              ...                                                ...
# 4634          52002F                            TOMAH VA MEDICAL CENTER
# 4641          52003F                        MILWAUKEE VA MEDICAL CENTER
# 4647          52004F                          MADISON VA MEDICAL CENTER
# 4761          53004F                         CHEYENNE VA MEDICAL CENTER
# 4762          53005F                         SHERIDAN VA MEDICAL CENTER
#
#                       Address 1                            City State  \
# ...

# %%
ba['Provider Number'].str.isnumeric().sum()
# Out:
# 4697

# %%
ba.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1      City State  ZIP Code      County  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301     HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 2          205 MARENGO STREET  FLORENCE    AL     35631  LAUDERDALE
# 3               702 N MAIN ST       OPP    AL     36467   COVINGTON
# 4         101 HOSPITAL CIRCLE   LUVERNE    AL     36049    CRENSHAW
#
#    Phone Number         Hospital Type  \
# 0    3347938701  Acute Care Hospitals
# 1    2565938310  Acute Care Hospitals
# 2    2567688400  Acute Care Hospitals
# 3    3344933541  Acute Care Hospitals
# 4    3343353374  Acute Care Hospitals
#
# ...

# %%
ba[~ba['Provider Number'].str.isnumeric()]
# Out:
#      Provider Number                                      Hospital Name  \
# 88            01014F                       BIRMINGHAM VA MEDICAL CENTER
# 97            01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 98            01021F                       TUSCALOOSA VA MEDICAL CENTER
# 183           03012F                          PHOENIX VA MEDICAL CENTER
# 186           03013F                    VA S. ARIZONA HEALTHCARE SYSTEM
# ...              ...                                                ...
# 4634          52002F                            TOMAH VA MEDICAL CENTER
# 4641          52003F                        MILWAUKEE VA MEDICAL CENTER
# 4647          52004F                          MADISON VA MEDICAL CENTER
# 4761          53004F                         CHEYENNE VA MEDICAL CENTER
# 4762          53005F                         SHERIDAN VA MEDICAL CENTER
#
#                       Address 1                            City State  \
# ...

# %%
ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4826 entries, 0 to 4825
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider Number     4826 non-null   object
#  1   Hospital Name       4826 non-null   object
#  2   Address 1           4826 non-null   object
#  3   City                4826 non-null   object
#  4   State               4826 non-null   object
#  5   ZIP Code            4826 non-null   int64
#  6   County              4826 non-null   object
#  7   Phone Number        4826 non-null   int64
#  8   Hospital Type       4826 non-null   object
#  9   Hospital Ownership  4826 non-null   object
#  10  Emergency Services  4826 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 414.9+ KB

# %%
ya = ba[~ba['Provider Number'].str.isnumeric()]

# %%
ya.head(126)
# Out:
#      Provider Number                                      Hospital Name  \
# 88            01014F                       BIRMINGHAM VA MEDICAL CENTER
# 97            01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 98            01021F                       TUSCALOOSA VA MEDICAL CENTER
# 183           03012F                          PHOENIX VA MEDICAL CENTER
# 186           03013F                    VA S. ARIZONA HEALTHCARE SYSTEM
# ...              ...                                                ...
# 4586          51003F                       CLARKSBURG VA MEDICAL CENTER
# 4590          51004F                       HUNTINGTON VA MEDICAL CENTER
# 4596          51005F                      MARTINSBURG VA MEDICAL CENTER
# 4634          52002F                            TOMAH VA MEDICAL CENTER
# 4641          52003F                        MILWAUKEE VA MEDICAL CENTER
#
#                       Address 1                            City State  \
# ...

# %%
ba.drop(columns='Provider Number',index=1,inplace=True)

# %%
ba.head()
# Out:
#                       Hospital Name                  Address 1       City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER     1108 ROSS CLARK CIRCLE     DOTHAN
# 2    ELIZA COFFEE MEMORIAL HOSPITAL         205 MARENGO STREET   FLORENCE
# 3          MIZELL MEMORIAL HOSPITAL              702 N MAIN ST        OPP
# 4       CRENSHAW COMMUNITY HOSPITAL        101 HOSPITAL CIRCLE    LUVERNE
# 5          HARTSELLE MEDICAL CENTER  201 PINE STREET NORTHWEST  HARTSELLE
#
#   State  ZIP Code      County  Phone Number         Hospital Type  \
# 0    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 2    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
# 5    AL     35640      MORGAN    2567736511  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services
# ...

# %%
ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4825 entries, 0 to 4825
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hospital Name       4825 non-null   object
#  1   Address 1           4825 non-null   object
#  2   City                4825 non-null   object
#  3   State               4825 non-null   object
#  4   ZIP Code            4825 non-null   int64
#  5   County              4825 non-null   object
#  6   Phone Number        4825 non-null   int64
#  7   Hospital Type       4825 non-null   object
#  8   Hospital Ownership  4825 non-null   object
#  9   Emergency Services  4825 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 414.6+ KB

# %% [markdown]
#  # numerical no numerical

# %%
ba.dtypes
# Out:
# Hospital Name         object
# Address 1             object
# City                  object
# State                 object
# ZIP Code               int64
# County                object
# Phone Number           int64
# Hospital Type         object
# Hospital Ownership    object
# Emergency Services    object
# dtype: object

# %%
ba.columns
# Out:
# Index(['Hospital Name', 'Address 1', 'City', 'State', 'ZIP Code', 'County',
#        'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services'],
#       dtype='object')

# %%
non_numerical  = ba.columns[ba.dtypes == 'object']

# %%
for i in ba.columns[ba.dtypes == 'object']:
    print(i)
# Out:
# Hospital Name
# Address 1
# City
# State
# County
# Hospital Type
# Hospital Ownership
# Emergency Services

# %%
numerical_columns = ba.columns[ba.dtypes != 'object']

# %%
for i in ba.columns[ba.dtypes != 'object']:
    print(i)
# Out:
# ZIP Code
# Phone Number
